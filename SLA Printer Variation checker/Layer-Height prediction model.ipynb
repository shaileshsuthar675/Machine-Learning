# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_excel('1- DoE and Data.xlsx')

# %%
df.head()
# Out:
#    StdOrder  RunOrder  Layer Height  Exposure Time  Light Off Delay  \
# 0        35         1         0.050           2.25               12
# 1        10         2         0.075           2.50               12
# 2         2         3         0.100           2.00               13
# 3        31         4         0.050           2.00               13
# 4        36         5         0.100           2.25               12
#
#   Orientation  Time  Diameter  Length  Height 1  Square Pin Width  \
# 0           Z   137     4.077  12.035     3.080             2.005
# 1           X    93     4.202  11.935     3.005             2.015
# 2           X    74     4.128  12.020     3.110             2.115
# 3           Z   143     4.148  11.970     3.100             1.975
# 4           Z    70     3.885  12.150     3.215             1.860
#
#    Square Pin Length  Height 2  Surface Roughness
# 0              2.125     7.040                2.2
# 1              1.975     7.055                1.9
# 2              2.070     7.090                2.5
# 3              2.070     7.010                2.0
# 4              2.045     7.010                5.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StdOrder           45 non-null     int64
#  1   RunOrder           45 non-null     int64
#  2   Layer Height       45 non-null     float64
#  3   Exposure Time      45 non-null     float64
#  4   Light Off Delay    45 non-null     int64
#  5   Orientation        45 non-null     object
#  6   Time               45 non-null     int64
#  7   Diameter           45 non-null     float64
#  8   Length             45 non-null     float64
#  9   Height 1           45 non-null     float64
#  10  Square Pin Width   45 non-null     float64
#  11  Square Pin Length  45 non-null     float64
#  12  Height 2           45 non-null     float64
#  13  Surface Roughness  45 non-null     float64
# dtypes: float64(9), int64(4), object(1)
# memory usage: 5.0+ KB

# %%
np.sum(df.isna())
# Out:
# StdOrder             0
# RunOrder             0
# Layer Height         0
# Exposure Time        0
# Light Off Delay      0
# Orientation          0
# Time                 0
# Diameter             0
# Length               0
# Height 1             0
# Square Pin Width     0
# Square Pin Length    0
# Height 2             0
# Surface Roughness    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['StdOrder', 'RunOrder', 'Layer Height', 'Exposure Time',
#        'Light Off Delay', 'Orientation', 'Time', 'Diameter', 'Length',
#        'Height 1', 'Square Pin Width', 'Square Pin Length', 'Height 2',
#        'Surface Roughness'],
#       dtype='object')

# %%
df.drop(['StdOrder', 'RunOrder','Time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Layer Height  Exposure Time  Light Off Delay Orientation  Diameter  Length  \
# 0         0.050           2.25               12           Z     4.077  12.035
# 1         0.075           2.50               12           X     4.202  11.935
# 2         0.100           2.00               13           X     4.128  12.020
# 3         0.050           2.00               13           Z     4.148  11.970
# 4         0.100           2.25               12           Z     3.885  12.150
#
#    Height 1  Square Pin Width  Square Pin Length  Height 2  Surface Roughness
# 0     3.080             2.005              2.125     7.040                2.2
# 1     3.005             2.015              1.975     7.055                1.9
# 2     3.110             2.115              2.070     7.090                2.5
# 3     3.100             1.975              2.070     7.010                2.0
# 4     3.215             1.860              2.045     7.010                5.2

# %%
df1=df.copy()

# %%
df1['Diameter']=df1['Diameter']-4
df1['Length']=df1['Length']-12
df1['Height 1']=df1['Height 1']-3
df1['Square Pin Width']=df1['Square Pin Width']-2
df1['Square Pin Length']=df1['Square Pin Length']-2
df1['Height 2']=df1['Height 2']-7

# %%
df1.head()
# Out:
#    Layer Height  Exposure Time  Light Off Delay Orientation  Diameter  Length  \
# 0         0.050           2.25               12           Z     0.077   0.035
# 1         0.075           2.50               12           X     0.202  -0.065
# 2         0.100           2.00               13           X     0.128   0.020
# 3         0.050           2.00               13           Z     0.148  -0.030
# 4         0.100           2.25               12           Z    -0.115   0.150
#
#    Height 1  Square Pin Width  Square Pin Length  Height 2  Surface Roughness
# 0     0.080             0.005              0.125     0.040                2.2
# 1     0.005             0.015             -0.025     0.055                1.9
# 2     0.110             0.115              0.070     0.090                2.5
# 3     0.100            -0.025              0.070     0.010                2.0
# 4     0.215            -0.140              0.045     0.010                5.2

# %%
cols= ['Diameter', 'Length','Height 1', 'Square Pin Width', 'Square Pin Length', 'Height 2']
for i in cols:
    try:
        df1.drop(df1[df1[i]==0].index[0],axis=0,inplace=True)
    except:
        df1

# %%
df1.rename(columns={'Layer Height':'lr_h','Exposure Time':'exp_t','Light Off Delay':'lod','Orientation':'orient',
                   'Diameter':'D1','Length':'L1','Height 1':'H1', 'Square Pin Width':'S1', 'Square Pin Length':'S2'
                    , 'Height 2':'H2','Surface Roughness':'surf_R'},inplace=True)

# %%
df1.columns
# Out:
# Index(['lr_h', 'exp_t', 'lod', 'orient', 'D1', 'L1', 'H1', 'S1', 'S2', 'H2',
#        'surf_R'],
#       dtype='object')

# %% [markdown]
# ### def gradient_descent(data,y):
#     W1=W2=W3=W4=W5=W6=bias=0
#     D1= data['D1']
#     L1= data['L1']
#     H1= data['H1']
#     S1= data['S1']
#     S2= data['S2']
#     H2= data['H2']
#     variation=['D1', 'L1', 'H1', 'S1', 'S2', 'H2']
#     iteration= 1000
#     n=len(data['D1'])
#     learning_rate= 0.001
#
#     for j in range(len(variation)):
#         for i in range(iteration):
#             weighted= W1*D1 + W2*L1 + W3*H1 + W4*S1 + W5*S2 + W6*H2 + bias
#             y_pred= 1/(1+np.exp(-weighted))
#             W1_derivative= -(2/n)*(np.dot(np.transpose(D1),(y-y_pred)))
#             W2_derivative= -(2/n)*(np.dot(np.transpose(L1),(y-y_pred)))
#             W3_derivative= -(2/n)*(np.dot(np.transpose(H1),(y-y_pred)))
#             W4_derivative= -(2/n)*(np.dot(np.transpose(S1),(y-y_pred)))
#             W5_derivative= -(2/n)*(np.dot(np.transpose(S2),(y-y_pred)))
#             W6_derivative= -(2/n)*(np.dot(np.transpose(H2),(y-y_pred)))
#             bias= -(2)*np.mean(y-y_pred)
#             W1=W1+W1_derivative*learning_rate
#             W2=W2+W2_derivative*learning_rate
#             W3=W3+W3_derivative*learning_rate
#             W4=W4+W4_derivative*learning_rate
#             W5=W5+W5_derivative*learning_rate
#             W6=W6+W6_derivative*learning_rate
#             if i == 999:
#                 cost={}
#                 cost[j]=[W1,W2,W3,W4,W5]
#                 print(cost)
#                 print(f"W1: {W1},W2: {W2},W3: {W3},W4: {W4},W5: {W5},W6: {W6},bias: {bias},iteation: {i}")
#         print(np.min(cost[j]))
#         small_weight_index= cost[j].index(np.min(cost[j]))
#         data[variation[small_weight_index]]=0
#         weight[small_weight_index]=0
#         print(small_weight_index)

# %% [markdown]
# ### def gradient_descent(data,y):
# W1=W2=W3=W4=W5=W6=bias=0
# D1= df1['D1'].tolist()
# L1= df1['L1'].tolist()
# H1= df1['H1'].tolist()
# S1= df1['S1'].tolist()
# S2= df1['S2'].tolist()
# H2= df1['H2'].tolist()
# variation=[]
# for t in range(len(D1)):
#     c=[]
#     c.append(D1[t])
#     c.append(L1[t])
#     c.append(H1[t])
#     c.append(S1[t])
#     c.append(S2[t])
#     c.append(H2[t])
#     variation.append(c)
# iteration= 1000
# n=len(df1['D1'])
# learning_rate= 0.001
# weight= [W1,W2,W3,W4,W5,W6]
# weight_derivative= [0,0,0,0,0,0]
#
# for j in range(len(variation)):
#     for i in range(iteration):
#         for h in range(len(variation)):
#             weighted= np.dot(variation[h],weight)+ bias
#             y_pred= 1/(1+np.exp(-weighted))
#             bias= -(2)*np.mean(y-y_pred)
#
#             for k in range(len(weight)):
#
#
#                 weight_derivative[k]= -(2/n)*(np.dot(variation[h],(y-y_pred)))
#
#                 weight[k]=weight[k]+weight_derivative[k]*learning_rate
#
#
#         if i == 999:
#             print(f"W1: {W1},W2: {W2},W3: {W3},W4: {W4},W5: {W5},W6: {W6},bias: {bias},iteation: {i}")
#
#         weight.remove(np.min(weight))
#         variation.remove(variation[weight.index(np.min(weight))])

# %%
df1.head()
# Out:
#     lr_h  exp_t  lod orient     D1     L1     H1     S1     S2     H2  surf_R
# 0  0.050   2.25   12      Z  0.077  0.035  0.080  0.005  0.125  0.040     2.2
# 1  0.075   2.50   12      X  0.202 -0.065  0.005  0.015 -0.025  0.055     1.9
# 2  0.100   2.00   13      X  0.128  0.020  0.110  0.115  0.070  0.090     2.5
# 3  0.050   2.00   13      Z  0.148 -0.030  0.100 -0.025  0.070  0.010     2.0
# 4  0.100   2.25   12      Z -0.115  0.150  0.215 -0.140  0.045  0.010     5.2

# %% [markdown]
# # Linear Regression model
# ### Input parameters are - variation in Diameter, Length, Height, and Square Pin Height and Width

# %%
x= df1[['D1','L1', 'H1', 'S1', 'S2', 'H2']]
y= df1.lr_h

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lr_model =LinearRegression()
for j in range(len(x_train.columns)-1):
    mse=[]
    for i in range(len(x_train.columns)):
        train_data=x_train.drop([x_train.columns[i]],axis=1)
        lr_model.fit(train_data,y_train)
        test_data= x_test.drop([x_test.columns[i]],axis=1)
        MSE=mean_squared_error(y_test,lr_model.predict(test_data))
        print('RMSE Value: ', MSE,'Removed by this columns: ',x_train.columns[i])
        mse.append(MSE)
    print('\n')
    mse.index(np.min(mse))
    x_train.drop([x_train.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
    x_test.drop([x_test.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
# Out:
# RMSE Value:  0.00022791787905913788 Removed by this columns:  D1
# RMSE Value:  0.0004719258030171429 Removed by this columns:  L1
# RMSE Value:  0.00023878384783091266 Removed by this columns:  H1
# RMSE Value:  0.00019358583268614624 Removed by this columns:  S1
# RMSE Value:  0.0004620984228796219 Removed by this columns:  S2
# RMSE Value:  0.0005063370923623295 Removed by this columns:  H2
#
#
# RMSE Value:  0.00019108162109992633 Removed by this columns:  D1
# RMSE Value:  0.000215317614848522 Removed by this columns:  L1
# RMSE Value:  0.00018052978781380946 Removed by this columns:  H1
# RMSE Value:  0.00023007220402322255 Removed by this columns:  S2
# RMSE Value:  0.00033228106943078266 Removed by this columns:  H2
#
#
# RMSE Value:  0.00021448004860662886 Removed by this columns:  D1
# RMSE Value:  0.0002189898171493452 Removed by this columns:  L1
# RMSE Value:  0.00020694282450458583 Removed by this columns:  S2
# RMSE Value:  0.0002833623617614284 Removed by this columns:  H2
#
#
# RMSE Value:  0.00021003538704037148 Removed by this columns:  D1
# RMSE Value:  0.0002945691305668251 Removed by this columns:  L1
# RMSE Value:  0.0003919684603562282 Removed by this columns:  H2
#
#
# RMSE Value:  0.00029657890562386174 Removed by this columns:  L1
# RMSE Value:  0.00032313039252778787 Removed by this columns:  H2

# %% [markdown]
# # Linear Regression model
# ### Input parameters are - variation in Diameter, Length, Height, and Square Pin Height and Width, Surface Roughness and Orientation

# %%
from sklearn.preprocessing import LabelEncoder
df1['orient']=LabelEncoder().fit_transform(df1['orient'])
x= df1[['D1','L1', 'H1', 'S1', 'S2', 'H2','orient','surf_R']]
y= df1.lr_h

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
surf_R_train_df=x_train[['surf_R','orient']]
x_train.drop(['surf_R','orient'],axis=1,inplace=True)
surf_R_test_df=x_test[['surf_R','orient']]
x_test.drop(['surf_R','orient'],axis=1,inplace=True)

import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lr_model =LinearRegression()
for j in range(len(x_train.columns)-1):
    mse=[]
    for i in range(len(x_train.columns)):
        train_data=x_train.drop([x_train.columns[i]],axis=1)
        train_data_1= pd.concat([train_data,surf_R_train_df],axis=1)
        lr_model.fit(train_data_1,y_train)
        
        test_data= x_test.drop([x_test.columns[i]],axis=1)
        test_data_1= pd.concat([test_data,surf_R_test_df],axis=1)
        MSE=mean_squared_error(y_test,lr_model.predict(test_data_1))
        print('RMSE Value: ', MSE,'Removed by this columns: ',x_train.columns[i])
        mse.append(MSE)
    print('\n')
    mse.index(np.min(mse))
    x_train.drop([x_train.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
    x_test.drop([x_test.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
# Out:
# RMSE Value:  0.0005929398050039041 Removed by this columns:  D1
# RMSE Value:  0.0006519476726746261 Removed by this columns:  L1
# RMSE Value:  0.0006013873388303871 Removed by this columns:  H1
# RMSE Value:  0.0001317127509896107 Removed by this columns:  S1
# RMSE Value:  0.00035430015401081906 Removed by this columns:  S2
# RMSE Value:  0.0004673440042020591 Removed by this columns:  H2
#
#
# RMSE Value:  0.00012670666014727542 Removed by this columns:  D1
# RMSE Value:  0.00012193294390039138 Removed by this columns:  L1
# RMSE Value:  0.00015625590291309827 Removed by this columns:  H1
# RMSE Value:  0.00012632015651087668 Removed by this columns:  S2
# RMSE Value:  0.00012704234796709379 Removed by this columns:  H2
#
#
# RMSE Value:  0.00011651109650672413 Removed by this columns:  D1
# RMSE Value:  0.00014685152384856474 Removed by this columns:  H1
# RMSE Value:  0.00010482651157667173 Removed by this columns:  S2
# RMSE Value:  0.00013931824658676567 Removed by this columns:  H2
#
#
# RMSE Value:  0.00010481186598545123 Removed by this columns:  D1
# RMSE Value:  0.00011409794073899936 Removed by this columns:  H1
# RMSE Value:  0.00014965103559030086 Removed by this columns:  H2
#
#
# RMSE Value:  0.0001036421843275241 Removed by this columns:  H1
# RMSE Value:  0.00011876526856826506 Removed by this columns:  H2

# %% [markdown]
# ### From this result for linear Regression model best variation parameter is **Height 2**, Who have major influences on **Layer Height** with respect to low value of RMSE.

# %% [markdown]
# # Ridge Regression
# ### Input parameters are - variation in Diameter, Length, Height, and Square Pin Height and Width, Surface Roughness and Orientation

# %%
from sklearn.preprocessing import LabelEncoder
df1['orient']=LabelEncoder().fit_transform(df1['orient'])
x= df1[['D1','L1', 'H1', 'S1', 'S2', 'H2','orient','surf_R']]
y= df1.lr_h

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
surf_R_train_df=x_train[['surf_R','orient']]
x_train.drop(['surf_R','orient'],axis=1,inplace=True)
surf_R_test_df=x_test[['surf_R','orient']]
x_test.drop(['surf_R','orient'],axis=1,inplace=True)

import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
ridge_model =Ridge()
for j in range(len(x_train.columns)-1):
    mse=[]
    for i in range(len(x_train.columns)):
        train_data=x_train.drop([x_train.columns[i]],axis=1)
        train_data_1= pd.concat([train_data,surf_R_train_df],axis=1)
        ridge_model.fit(train_data_1,y_train)
        
        test_data= x_test.drop([x_test.columns[i]],axis=1)
        test_data_1= pd.concat([test_data,surf_R_test_df],axis=1)
        MSE=mean_squared_error(y_test,ridge_model.predict(test_data_1))
        print('RMSE Value: ', MSE,'Removed by this columns: ',x_train.columns[i])
        mse.append(MSE)
    print('\n')
    mse.index(np.min(mse))
    x_train.drop([x_train.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
    x_test.drop([x_test.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
# Out:
# RMSE Value:  0.00011120991075199091 Removed by this columns:  D1
# RMSE Value:  0.00011157362023143338 Removed by this columns:  L1
# RMSE Value:  0.00011143868562692097 Removed by this columns:  H1
# RMSE Value:  0.00011187624288951396 Removed by this columns:  S1
# RMSE Value:  0.00011093299671506325 Removed by this columns:  S2
# RMSE Value:  0.00011992739050384112 Removed by this columns:  H2
#
#
# RMSE Value:  0.00011057634814668228 Removed by this columns:  D1
# RMSE Value:  0.00011099514248678926 Removed by this columns:  L1
# RMSE Value:  0.00011092996290997775 Removed by this columns:  H1
# RMSE Value:  0.00011130439487949904 Removed by this columns:  S1
# RMSE Value:  0.00011946735903945373 Removed by this columns:  H2
#
#
# RMSE Value:  0.0001106404724335423 Removed by this columns:  L1
# RMSE Value:  0.00011058109234870616 Removed by this columns:  H1
# RMSE Value:  0.00011099162805981793 Removed by this columns:  S1
# RMSE Value:  0.00011890025230856978 Removed by this columns:  H2
#
#
# RMSE Value:  0.00011064521750667533 Removed by this columns:  L1
# RMSE Value:  0.00011096386891829519 Removed by this columns:  S1
# RMSE Value:  0.00011909016805750831 Removed by this columns:  H2
#
#
# RMSE Value:  0.00011103077520553851 Removed by this columns:  S1
# RMSE Value:  0.00011933729719651165 Removed by this columns:  H2

# %% [markdown]
# # KNN Regressor
# ### Input parameters are - variation in Diameter, Length, Height, and Square Pin Height and Width, Surface Roughness and Orientation

# %%
from sklearn.preprocessing import LabelEncoder
df1['orient']=LabelEncoder().fit_transform(df1['orient'])
x= df1[['D1','L1', 'H1', 'S1', 'S2', 'H2','orient','surf_R']]
y= df1.lr_h

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

surf_R_train_df=x_train[['surf_R','orient']]
x_train.drop(['surf_R','orient'],axis=1,inplace=True)
surf_R_test_df=x_test[['surf_R','orient']]
x_test.drop(['surf_R','orient'],axis=1,inplace=True)

import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
KNN_model =KNeighborsRegressor()
for j in range(len(x_train.columns)-1):
    mse=[]
    for i in range(len(x_train.columns)):
        train_data=x_train.drop([x_train.columns[i]],axis=1)
        train_data_1= pd.concat([train_data,surf_R_train_df],axis=1)
        KNN_model.fit(train_data_1,y_train)
        
        test_data= x_test.drop([x_test.columns[i]],axis=1)
        test_data_1= pd.concat([test_data,surf_R_test_df],axis=1)
        MSE=mean_squared_error(y_test,KNN_model.predict(test_data_1))
        print('RMSE Value: ', MSE,'Removed by this columns: ',x_train.columns[i])
        mse.append(MSE)
    print('\n')
    mse.index(np.min(mse))
    x_train.drop([x_train.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
    x_test.drop([x_test.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
# Out:
# RMSE Value:  0.00018611111111111118 Removed by this columns:  D1
# RMSE Value:  0.00018888888888888894 Removed by this columns:  L1
# RMSE Value:  0.00018888888888888894 Removed by this columns:  H1
# RMSE Value:  0.00018888888888888894 Removed by this columns:  S1
# RMSE Value:  0.00018611111111111118 Removed by this columns:  S2
# RMSE Value:  0.00018611111111111118 Removed by this columns:  H2
#
#
# RMSE Value:  0.00018888888888888894 Removed by this columns:  L1
# RMSE Value:  0.00018888888888888894 Removed by this columns:  H1
# RMSE Value:  0.00018611111111111118 Removed by this columns:  S1
# RMSE Value:  0.00018611111111111118 Removed by this columns:  S2
# RMSE Value:  0.00018611111111111115 Removed by this columns:  H2
#
#
# RMSE Value:  0.00016944444444444448 Removed by this columns:  L1
# RMSE Value:  0.0001888888888888889 Removed by this columns:  H1
# RMSE Value:  0.00018611111111111115 Removed by this columns:  S1
# RMSE Value:  0.00018611111111111118 Removed by this columns:  S2
#
#
# RMSE Value:  0.00016944444444444448 Removed by this columns:  H1
# RMSE Value:  0.0001888888888888889 Removed by this columns:  S1
# RMSE Value:  0.00018611111111111115 Removed by this columns:  S2
#
#
# RMSE Value:  0.00016944444444444448 Removed by this columns:  S1
# RMSE Value:  0.00016944444444444448 Removed by this columns:  S2

# %%
from sklearn.preprocessing import LabelEncoder
df1['orient']=LabelEncoder().fit_transform(df1['orient'])
x= df1[['D1','L1', 'H1', 'S1', 'S2', 'H2','orient','surf_R']]
y= df1.lr_h

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

surf_R_train_df=x_train[['surf_R','orient']]
x_train.drop(['surf_R','orient'],axis=1,inplace=True)
surf_R_test_df=x_test[['surf_R','orient']]
x_test.drop(['surf_R','orient'],axis=1,inplace=True)

import warnings
warnings.filterwarnings('ignore')
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
dec_tree_model =DecisionTreeRegressor()
for j in range(len(x_train.columns)-1):
    mse=[]
    for i in range(len(x_train.columns)):
        train_data=x_train.drop([x_train.columns[i]],axis=1)
        train_data_1= pd.concat([train_data,surf_R_train_df],axis=1)
        dec_tree_model.fit(train_data_1,y_train)
        
        test_data= x_test.drop([x_test.columns[i]],axis=1)
        test_data_1= pd.concat([test_data,surf_R_test_df],axis=1)
        MSE=mean_squared_error(y_test,dec_tree_model.predict(test_data_1))
        print('RMSE Value: ', MSE,'Removed by this columns: ',x_train.columns[i])
        mse.append(MSE)
    print('\n')
    mse.index(np.min(mse))
    x_train.drop([x_train.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
    x_test.drop([x_test.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
# Out:
# RMSE Value:  0.00013888888888888894 Removed by this columns:  D1
# RMSE Value:  0.0002777777777777777 Removed by this columns:  L1
# RMSE Value:  0.0002777777777777777 Removed by this columns:  H1
# RMSE Value:  0.0002777777777777778 Removed by this columns:  S1
# RMSE Value:  0.0002777777777777779 Removed by this columns:  S2
# RMSE Value:  0.00027777777777777783 Removed by this columns:  H2
#
#
# RMSE Value:  0.00020833333333333335 Removed by this columns:  L1
# RMSE Value:  0.0003472222222222221 Removed by this columns:  H1
# RMSE Value:  0.00020833333333333343 Removed by this columns:  S1
# RMSE Value:  0.00020833333333333348 Removed by this columns:  S2
# RMSE Value:  0.00020833333333333332 Removed by this columns:  H2
#
#
# RMSE Value:  0.0005555555555555557 Removed by this columns:  L1
# RMSE Value:  0.0005555555555555557 Removed by this columns:  H1
# RMSE Value:  0.00048611111111111115 Removed by this columns:  S1
# RMSE Value:  0.00034722222222222234 Removed by this columns:  S2
#
#
# RMSE Value:  0.0003472222222222224 Removed by this columns:  L1
# RMSE Value:  0.0006944444444444447 Removed by this columns:  H1
# RMSE Value:  0.00034722222222222234 Removed by this columns:  S1
#
#
# RMSE Value:  0.00048611111111111126 Removed by this columns:  L1
# RMSE Value:  0.00027777777777777794 Removed by this columns:  H1

# %% [markdown]
# # DNN Model

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.preprocessing import LabelEncoder
df1['orient']=LabelEncoder().fit_transform(df1['orient'])
x= df1[['D1','L1', 'H1', 'S1', 'S2', 'H2','orient','surf_R']]
y= df1.lr_h

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

surf_R_train_df=x_train[['surf_R','orient']]
x_train.drop(['surf_R','orient'],axis=1,inplace=True)
surf_R_test_df=x_test[['surf_R','orient']]
x_test.drop(['surf_R','orient'],axis=1,inplace=True)

import warnings
warnings.filterwarnings('ignore')


for j in range(len(x_train.columns)-1):
    mse=[]
    for i in range(len(x_train.columns)):
        dnn_model= keras.Sequential([keras.layers.Dense((len(x_train.columns)+1),input_shape=((len(x_train.columns)+1),),activation='relu'),
                                     keras.layers.Dense(1,activation='sigmoid')])

        dnn_model.compile(optimizer='adam',
                          loss='binary_crossentropy')
        train_data=x_train.drop([x_train.columns[i]],axis=1)
        train_data_1= pd.concat([train_data,surf_R_train_df],axis=1)
        dnn_model.fit(train_data_1,y_train,epochs=500,verbose=False)
        
        test_data= x_test.drop([x_test.columns[i]],axis=1)
        test_data_1= pd.concat([test_data,surf_R_test_df],axis=1)
        MSE=mean_squared_error(y_test,dnn_model.predict(test_data_1))
        print('RMSE Value: ', MSE,'Removed by this columns: ',x_train.columns[i])
        mse.append(MSE)
    print('\n')
    mse.index(np.min(mse))
    x_train.drop([x_train.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
    x_test.drop([x_test.columns[mse.index(np.min(mse))]],axis=1,inplace=True)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# RMSE Value:  0.0026291366199678906 Removed by this columns:  D1
# 1/1 [==============================] - 0s 46ms/step
# RMSE Value:  0.003727630250879697 Removed by this columns:  L1
# 1/1 [==============================] - 0s 37ms/step
# RMSE Value:  0.0030411682707139434 Removed by this columns:  H1
# 1/1 [==============================] - 0s 38ms/step
# RMSE Value:  0.004082927930059194 Removed by this columns:  S1
# 1/1 [==============================] - 0s 38ms/step
# RMSE Value:  0.003211852299446239 Removed by this columns:  S2
# 1/1 [==============================] - 0s 38ms/step
# RMSE Value:  0.004492699350161767 Removed by this columns:  H2
#
#
# 1/1 [==============================] - 0s 40ms/step
# RMSE Value:  0.003358041020503647 Removed by this columns:  L1
# 1/1 [==============================] - 0s 45ms/step
# RMSE Value:  0.0029907064054539873 Removed by this columns:  H1
# 1/1 [==============================] - 0s 51ms/step
# RMSE Value:  0.0033797613805202865 Removed by this columns:  S1
# 1/1 [==============================] - 0s 39ms/step
# RMSE Value:  0.0034554725476889582 Removed by this columns:  S2
# 1/1 [==============================] - 0s 39ms/step
# RMSE Value:  0.0035107649878629438 Removed by this columns:  H2
#
#
# 1/1 [==============================] - 0s 38ms/step
# RMSE Value:  0.003745407048376916 Removed by this columns:  L1
# 1/1 [==============================] - 0s 38ms/step
# RMSE Value:  0.14413307013905596 Removed by this columns:  S1
# 1/1 [==============================] - 0s 39ms/step
# RMSE Value:  0.008501497371294136 Removed by this columns:  S2
# 1/1 [==============================] - 0s 43ms/step
# RMSE Value:  0.004500896379944395 Removed by this columns:  H2
#
#
# 1/1 [==============================] - 0s 46ms/step
# RMSE Value:  0.004294172414421462 Removed by this columns:  S1
# 1/1 [==============================] - 0s 42ms/step
# RMSE Value:  0.0034760708651271504 Removed by this columns:  S2
# 1/1 [==============================] - 0s 41ms/step
# RMSE Value:  0.004289342886519157 Removed by this columns:  H2
#
#
# 1/1 [==============================] - 0s 41ms/step
# RMSE Value:  0.0016959124802877182 Removed by this columns:  S1
# 1/1 [==============================] - 0s 38ms/step
# RMSE Value:  0.10165634076653121 Removed by this columns:  H2
